# %% [markdown]
# # (4주차) 9월28일 -- draft
# > seaborn
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: 최규빈

# %% [markdown]
# ## imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %% [markdown]
# ## seaborn 특징

# %% [markdown]
# `-` 특1: 입력으로 데이터프레임을 선호한다. (matplotlib은 array를 선호)
# - 그렇다고 해서 데이터프레임이 아닌 경우 그림이 아예 안 그려지지는 않는다.
# - 데이터프레임 형태는 long form 과 wide form 이 있다. [(ref)](https://seaborn.pydata.org/tutorial/data_structure.html#long-form-vs-wide-form-data) // 참고로 long form이 더 우수한 저장형태에요!

# %% [markdown]
# `-` 특2: matplotlib을 존경함. ([ref](https://seaborn.pydata.org/index.html))

# %% [markdown]
# ## [sns boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %% [markdown]
# `-` 데이터: 전북고등학교

# %%
y1=[75,75,76,76,77,77,79,79,79,98] # A선생님에게 통계학을 배운 학생의 점수들
y2=[76,76,77,77,78,78,80,80,80,81] # B선생님에게 통계학을 배운 학생의 점수들

# %% [markdown]
# ### plt 복습

# %%
plt.boxplot([y1,y2]);

# %% [markdown]
# ### sns wide df

# %%
#
# Out:
#     1   2
# 0  75  76
# 1  75  76
# 2  76  77
# 3  76  77
# 4  77  78
# 5  77  78
# 6  79  80
# 7  79  80
# 8  79  80
# 9  98  81

# %% [markdown]
# `-` 예시1

# %%
sns.boxplot(data=df1) 
# sns.boxplot(np.stack([y1,y2],axis=1))  # <- 잘 쓰진 않아요, 그냥 심심해서 해봤는데 되더라고요..?
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### sns long df

# %%
#
# Out:
#     score class
# 0      75     A
# 1      75     A
# 2      76     A
# 3      76     A
# 4      77     A
# 5      77     A
# 6      79     A
# 7      79     A
# 8      79     A
# 9      98     A
# 10     76     B
# 11     76     B
# 12     77     B
# 13     77     B
# 14     78     B
# 15     78     B
# 16     80     B
# 17     80     B
# 18     80     B
# 19     81     B

# %% [markdown]
# `-` 예시1

# %%
sns.boxplot(data=df2,x='class',y='score')
# Out:
# <AxesSubplot:xlabel='class', ylabel='score'>

# %% [markdown]
# ### sns: array

# %% [markdown]
# `-` 예시1

# %%
sns.boxplot(data=y1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시2

# %%
sns.boxplot(y=y1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시3

# %%
sns.boxplot(x=y1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시4

# %%
sns.boxplot(data=y2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시5

# %%
sns.boxplot(y=y2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시6

# %%
sns.boxplot(x=y2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## [sns histplot](https://seaborn.pydata.org/generated/seaborn.histplot.html)

# %% [markdown]
# `-` 데이터

# %%
x= np.random.randn(10000) 
y= np.random.randn(10000) +1

# %% [markdown]
# ### plt 복습

# %% [markdown]
# `-` 예시1

# %%
plt.hist(x,alpha=0.5)
plt.hist(y,alpha=0.5)
# Out:
# (array([   9.,   60.,  400., 1383., 2718., 2985., 1742.,  576.,  116.,
#           11.]),
#  array([-3.0752867 , -2.2812862 , -1.4872857 , -0.6932852 ,  0.1007153 ,
#          0.8947158 ,  1.68871631,  2.48271681,  3.27671731,  4.07071781,
#          4.86471831]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# `-` 예시2

# %%
plt.hist([x,y])
# Out:
# (array([[   9.,  101.,  668., 2224., 3473., 2553.,  829.,  130.,   13.,
#             0.],
#         [   0.,    7.,   72.,  549., 2027., 3463., 2656., 1019.,  193.,
#            14.]]),
#  array([-4.12186916, -3.22321042, -2.32455167, -1.42589292, -0.52723417,
#          0.37142457,  1.27008332,  2.16874207,  3.06740081,  3.96605956,
#          4.86471831]),
#  <a list of 2 BarContainer objects>)

# %% [markdown]
# ### sns: wide df

# %%
#
# Out:
#              x         y
# 0    -0.250273  1.172989
# 1    -1.580452 -1.181606
# 2     0.112415  1.387470
# 3    -2.384201  1.462842
# 4     0.785381  1.685293
# ...        ...       ...
# 9995  0.727114  3.786212
# 9996 -0.640880 -0.977741
# 9997  0.436365  0.911048
# 9998  0.396089 -0.446357
# 9999 -0.066229  0.592237
#
# [10000 rows x 2 columns]

# %% [markdown]
# `-` 예시1

# %%
sns.histplot(data=df1)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# `-` 예시2

# %%
sns.histplot(data=df1,bins=20)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# `-` 예시3

# %%
sns.histplot(data=df1,bins=20,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# `-` 예시4

# %%
sns.histplot(data=df1,bins=20,kde=True,element="step")
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# `-` 예시5

# %%
sns.histplot(data=df1,bins=20,kde=True,element="step",lw=5) # mpl에 대한 존경심 확인
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### sns: long df

# %%
#
# Out:
#             val var
# 0     -0.250273   x
# 1     -1.580452   x
# 2      0.112415   x
# 3     -2.384201   x
# 4      0.785381   x
# ...         ...  ..
# 19995  3.786212   y
# 19996 -0.977741   y
# 19997  0.911048   y
# 19998 -0.446357   y
# 19999  0.592237   y
#
# [20000 rows x 2 columns]

# %% [markdown]
# `-` 예시1

# %%
sns.histplot(data=df2,x='val',hue='var',bins=20,kde=True,lw=0)
# Out:
# <AxesSubplot:xlabel='val', ylabel='Count'>

# %% [markdown]
# `-` 예시2

# %%
sns.histplot(data=df2,y='val',hue='var',bins=20,lw=0,kde=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='val'>

# %% [markdown]
# ### sns: array

# %% [markdown]
# `-` 예시1

# %%
sns.histplot(x=x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# `-` 예시2

# %%
sns.histplot(data=x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# `-` 예시3

# %%
sns.histplot(x=x,color='C0',bins=20,lw=0)
sns.histplot(x=y,color='C1',bins=20,lw=0)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## [sns lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html)

# %% [markdown]
# `-` data

# %%
np.random.seed(43052)
ϵ = np.random.randn(100)

# %%
y = np.cumsum(ϵ)

# %% [markdown]
# ### plt 복습

# %%
plt.plot(ϵ,'--o')

# %%
plt.plot(y,'--o')

# %% [markdown]
# ### sns: array

# %% [markdown]
# `-` 예시1

# %%
sns.lineplot(data=ϵ)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시2

# %%
sns.lineplot(data=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### sns: wide df

# %%
#
# Out:
#      epsilon          y
# 0   0.383420   0.383420
# 1   1.084175   1.467595
# 2   1.142778   2.610373
# 3   0.307894   2.918267
# 4   0.237787   3.156054
# ..       ...        ...
# 95  1.308688 -10.598788
# 96  0.405376 -10.193412
# 97 -0.185070 -10.378481
# 98  1.055388  -9.323094
# 99  1.187014  -8.136079
#
# [100 rows x 2 columns]

# %% [markdown]
# `-` 예시1

# %%
sns.lineplot(data=df1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시2

# %%
sns.lineplot(data=df1,dashes=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시3

# %%
sns.lineplot(data=df1,dashes=[(3,1),(3,3)])
# Out:
# <AxesSubplot:>

# %% [markdown]
# `-` 예시4

# %%
sns.lineplot(data=df1,dashes=[(3,1),(3,3)],markers=['o','o'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### sns: long df

# %%
#
# Out:
#       x          y  var
# 0     0   0.383420  eps
# 1     1   1.084175  eps
# 2     2   1.142778  eps
# 3     3   0.307894  eps
# 4     4   0.237787  eps
# ..   ..        ...  ...
# 195  95 -10.598788    y
# 196  96 -10.193412    y
# 197  97 -10.378481    y
# 198  98  -9.323094    y
# 199  99  -8.136079    y
#
# [200 rows x 3 columns]

# %% [markdown]
# `-` 예시1

# %%
sns.lineplot(data=df2, x='x',y='y',hue='var')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# `-` 예시2

# %%
sns.lineplot(data=df2, x='x',y='y',style='var',hue='var',markers=True)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# `-` 예시3

# %%
sns.lineplot(data=df2, x='x',y='y',style='var',hue='var',dashes=[(3,1),(3,3)],markers=['o','o'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ## [sns scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %% [markdown]
# `-` data

# %%
np.random.seed(43052)
ϵ = np.random.randn(100)
y = np.cumsum(ϵ)

# %%
ϵ1 = ϵ[1:] # (t-1) 시점
ϵ2 = ϵ[:-1] # t 시점

# %%
y1 = y[1:] # (t-1) 시점 
y2 = y[:-1] # t 시점

# %% [markdown]
# ### plt 복습

# %% [markdown]
# `-` 예시1

# %%
plt.plot(ϵ1,ϵ2,'o')

# %%
np.corrcoef(ϵ1,ϵ2) # np.corrcoef([ϵ1,ϵ2])
# Out:
# array([[1.        , 0.05289696],
#        [0.05289696, 1.        ]])

# %% [markdown]
# `-` 예시2

# %%
plt.plot(y1,y2,'o')

# %%
np.corrcoef(y1,y2)
# Out:
# array([[1.        , 0.97237553],
#        [0.97237553, 1.        ]])

# %% [markdown]
# ### sns: array

# %%
sns.scatterplot(data=None,x=y1,y=y2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### sns: wide df

# %% [markdown]
# `-` 예시1

# %%
sns.scatterplot(data=pd.DataFrame({'eps1':ϵ1,'eps2':ϵ2}), x='eps1', y='eps2')
# Out:
# <AxesSubplot:xlabel='eps1', ylabel='eps2'>

# %% [markdown]
# `-` 예시2

# %%
sns.scatterplot(data=pd.DataFrame({'y1':y1,'y2':y2}), x='y1', y='y2')
# Out:
# <AxesSubplot:xlabel='y1', ylabel='y2'>

# %% [markdown]
# `-` 예시3

# %%
sns.scatterplot(data=pd.DataFrame({'eps1':ϵ1,'eps2':ϵ2}), x='eps1', y='eps2')
sns.scatterplot(data=pd.DataFrame({'y1':y1,'y2':y2}), x='y1', y='y2')
# Out:
# <AxesSubplot:xlabel='eps1', ylabel='eps2'>

# %% [markdown]
# ### sns: long df

# %%
_x = np.concatenate([ϵ1,y1])
_y = np.concatenate([ϵ2,y2])
_var = ['eps']*len(ϵ1)+['y']*len(y1)

# %%
#
# Out:
#              x          y  var
# 0     1.084175   0.383420  eps
# 1     1.142778   1.084175  eps
# 2     0.307894   1.142778  eps
# 3     0.237787   0.307894  eps
# 4     0.355951   0.237787  eps
# ..         ...        ...  ...
# 193 -10.598788 -11.907476    y
# 194 -10.193412 -10.598788    y
# 195 -10.378481 -10.193412    y
# 196  -9.323094 -10.378481    y
# 197  -8.136079  -9.323094    y
#
# [198 rows x 3 columns]

# %% [markdown]
# `-` 예시1

# %%
sns.scatterplot(data=df2,x='x',y='y',hue='var')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ## seaborn: figure-level vs axes-level

# %% [markdown]
# ref: https://seaborn.pydata.org/tutorial/function_overview.html#figure-level-vs-axes-level-functions

# %% [markdown]
# ### 예제1

# %% [markdown]
# `-` 지금까지 살펴본 boxplot, histplot, lineplot, scatterplot 의 공통점 = 액시즈레벨 함수임 (함수의 argument로 ax를 명시할 수 있다)

# %%
fig,myax = plt.subplots()

# %%
sns.histplot(data=np.random.randn(100), ax=myax)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
fig

# %%
myax.set_ylabel('count',size=20,family='serif',style='italic',weight=700)
# Out:
# Text(27.200000000000003, 0.5, 'count')

# %%
fig

# %% [markdown]
# ### 예제2

# %% [markdown]
# `-` data

# %%
import cv2

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/0/08/Unequalized_Hawkes_Bay_NZ.jpg
img_before = cv2.imread('Unequalized_Hawkes_Bay_NZ.jpg',0)
# !rm Unequalized_Hawkes_Bay_NZ.jpg
# Out:
# --2022-09-28 14:48:28--  https://upload.wikimedia.org/wikipedia/commons/0/08/Unequalized_Hawkes_Bay_NZ.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 103.102.166.240, 2001:df2:e500:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|103.102.166.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110895 (108K) [image/jpeg]
# Saving to: ‘Unequalized_Hawkes_Bay_NZ.jpg’
#
# Unequalized_Hawkes_ 100%[===================>] 108.30K   544KB/s    in 0.2s
#
# 2022-09-28 14:48:28 (544 KB/s) - ‘Unequalized_Hawkes_Bay_NZ.jpg’ saved [110895/110895]

# %% [markdown]
# (for win user)
# ```python
# !pip install wget # 처음한번만 실행
#
# import wget
# wget.download('https://upload.wikimedia.org/wikipedia/commons/0/08/Unequalized_Hawkes_Bay_NZ.jpg')
# img_before = cv2.imread('Unequalized_Hawkes_Bay_NZ.jpg',0)
# ```

# %%
img_before
# Out:
# array([[127, 145, 149, ..., 168, 167, 166],
#        [165, 152, 143, ..., 168, 169, 168],
#        [171, 145, 140, ..., 156, 154, 151],
#        ...,
#        [147, 132, 134, ..., 146, 145, 144],
#        [146, 130, 132, ..., 146, 145, 144],
#        [145, 128, 129, ..., 146, 145, 144]], dtype=uint8)

# %%
img_after = cv2.equalizeHist(img_before)

# %%
fig, ax = plt.subplots(2,2,figsize=(10,5))
ax[0,0].imshow(img_before,cmap='gray',vmin=0,vmax=255)
sns.histplot(data=img_before.reshape(-1),ax=ax[0,1],bins=15,kde=True,color='C1',lw=0); ax[0,1].set_xlim(0,255)
ax[1,0].imshow(img_after,cmap='gray',vmin=0,vmax=255); 
sns.histplot(data=img_after.reshape(-1),ax=ax[1,1],bins=15,kde=True,color='C1',lw=0); ax[1,1].set_xlim(0,255)
fig.tight_layout()

# %% [markdown]
# ## mpl 미세먼지팁 (2)

# %% [markdown]
# ### Latex

# %% [markdown]
# `-` 예시1

# %%
x1= np.linspace(-2,2,1000)
y1= (x1-1)**2 
plt.plot(x1,y1,'--')
plt.title('$y_1=(x_1-1)^2$');

# %% [markdown]
# `-` 예시2

# %%
x1 = np.linspace(-2,2,1000)
y1 = 0.5*(x1-1)**2 
plt.plot(x1,y1,'--')
plt.title(r'$y_1=\frac{1}{2}(x_1-1)^2$',size=20);

# %% [markdown]
# `-` 예시3

# %%
x1 = np.linspace(-2,2,1000)
y1 = 0.5*(x1-1)**2 
plt.plot(x1,y1,'--')
plt.title(r'$y_1=\frac{1}{2}(x_1-1)^2$',size=20)
plt.xlabel(r'$x_1$',size=15)
plt.ylabel(r'$y_1$',size=15);

# %% [markdown]
# `-` 예시4

# %%
x1 = np.linspace(-2,2,1000)
y1 = 0.5*(x1-1)**2 
y2 = 0.5*(x1+1)**2
plt.plot(x1,y1,'--',label=r'$\frac{1}{2}(x-1)^2$')
plt.plot(x1,y2,'--',label=r'$\frac{1}{2}(x+1)^2$')
plt.legend()

# %% [markdown]
# ### gcf, gca

# %% [markdown]
# `-` gcf

# %%
plt.plot([1,2,3,2])
fig = plt.gcf()

# %%
fig.suptitle('suptitle')
# Out:
# Text(0.5, 0.98, 'suptitle')

# %%
fig

# %% [markdown]
# `-` gca

# %%
fig

# %%
ax = fig.gca()

# %%
ax.set_title('title') 
fig
